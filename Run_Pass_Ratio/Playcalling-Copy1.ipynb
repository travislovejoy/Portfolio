# %%
import pandas as pd
import numpy as np
import seaborn as sns
import scipy.stats as stats

# %%
plays = pd.read_csv('/home/travis/NFL/Analysis/Run_Pass_Ratio/Data/TimePlaycalling.csv')

plays.describe()
# Out:
#             gsis_id       drive_id     home_score     away_score  \
# count  3.620040e+05  362004.000000  362004.000000  362004.000000
# mean   2.012664e+09      12.344043      11.832983      10.437852
# std    2.292646e+06       7.168458      10.218419       9.563541
# min    2.009091e+09       1.000000       0.000000       0.000000
# 25%    2.011091e+09       6.000000       3.000000       3.000000
# 50%    2.013091e+09      12.000000      10.000000       7.000000
# 75%    2.015091e+09      18.000000      17.000000      17.000000
# max    2.017010e+09      35.000000      62.000000      59.000000
#
#                 pass           rush
# count  362004.000000  362004.000000
# mean        0.418459       0.304513
# std         0.493441       0.460232
# min         0.000000       0.000000
# 25%         0.000000       0.000000
# 50%         0.000000       0.000000
# 75%         1.000000       1.000000
# max         2.000000       2.000000

# %%
# Remove plays that are not pass or rush plays ie. Kickoff, Punts, Penalty etc.

plays=plays[(plays['pass']!=0) | (plays['rush']!=0)]

# %%
#Create A new Column called pointdiff which calculates the Possesing teams point diff
# Example a team w/ possesion leading by 5 would have a point diff of 5, while a team losing by 5 would have pointdiff of -5 
plays['pointdiff']=0
plays.loc[plays['pos_team']== plays['home'], 'pointdiff']= plays.loc[plays['pos_team']== plays['home'], 'home_score']- plays.loc[plays['pos_team']== plays['home'], 'away_score']
plays.loc[plays['pos_team']== plays['away'], 'pointdiff']= plays.loc[plays['pos_team']== plays['away'], 'away_score']- plays.loc[plays['pos_team']== plays['away'], 'home_score']
#df.loc[df['line_race'] == 0, 'rating'] = 0

# %%
#Group into quarters
quarterOne=plays[plays['quarter']=='1']
quarterTwo=plays[plays['quarter']=='2']
quarterThree=plays[plays['quarter']=='3']
quarterFour=plays[plays['quarter']=='4']
Overtime=plays[plays['quarter']=='T']

#.agg({'pass': ['mean', 'count'], 'rush': 'mean'})

# %%
#Group by point differential of possesing team
#remove groups with fewer than 20 rows
# Calculate mean rush, which gives us the run/pass ratio

#Quarter One
grouped=quarterOne.groupby(['pointdiff'])
grouped=grouped.filter(lambda x: len(x) > 20)
quarterOne=grouped.groupby(['pointdiff']).agg({'rush': ['mean', 'count'], 'pass': 'mean'})

#Quarter Two
grouped=quarterTwo.groupby(['pointdiff'])
grouped=grouped.filter(lambda x: len(x) > 20)
quarterTwo=grouped.groupby(['pointdiff']).agg({'rush': ['mean', 'count'], 'pass': 'mean'})

#Quarter Three
grouped=quarterThree.groupby(['pointdiff'])
grouped=grouped.filter(lambda x: len(x) > 20)
quarterThree=grouped.groupby(['pointdiff']).agg({'rush': ['mean', 'count'], 'pass': 'mean'})


#Quarter Four
grouped=quarterFour.groupby(['pointdiff'])
grouped=grouped.filter(lambda x: len(x) > 20)
quarterFour=grouped.groupby(['pointdiff']).agg({'rush': ['mean', 'count'], 'pass': 'mean'})

# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax1=plt.subplot2grid((12,12), (0,0), rowspan=5, colspan=5)
ax2=plt.subplot2grid((12,12), (0,6),  rowspan=5, colspan=5)
ax3=plt.subplot2grid((12,12), (6,0), rowspan=5, colspan=5)
ax4=plt.subplot2grid((12,12), (6,6), rowspan=5, colspan=5)
#quarterOne=quarterOne.groupby(['pointdiff'])['pass', 'rush'].mean()
#quarterOne=grouped.groupby(['pointdiff']).agg({'pass': ['mean', 'count'], 'rush': 'mean'})
#plt.title('Run/Pass ratio')
ax1.scatter(quarterOne.index, quarterOne['pass'])

ax1.axhline(.5, color='grey', linewidth=2)

ax1.set_yticks([.2,.3,.4,.5,.6,.7,.8,])
ax1.set_xticks([-20,-15,-10,-5,0,5,10,15,20])
ax1.set_title('First Quarter')
ax1.set_xlim(-22,22)

ax2.scatter(quarterTwo.index, quarterTwo['pass'])
ax2.axhline(.5, color='grey', linewidth=2)
ax2.set_title('Second Quarter')
#ax2.set_yticks([.2,.3,.4,.5,.6,.7,.8,.9])

ax3.scatter(quarterThree.index, quarterThree['pass'])
ax3.axhline(.5, color='grey', linewidth=2)
ax3.set_title('Third Quarter')

ax4.scatter(quarterFour.index, quarterFour['pass'])
ax4.axhline(.5, color='grey', linewidth=2)
ax4.set_title('Fourth Quarter')
# Out:
# <img src="data:image/png;base64,...">

# %%
#fig, ax = plt.subplots()
fig, (ax1, ax2, ax3,ax4) = plt.subplots(nrows=4, ncols=1, sharex=False)
#quarterOne=quarterOne.groupby(['pointdiff'])['pass', 'rush'].mean()
#quarterOne=grouped.groupby(['pointdiff']).agg({'pass': ['mean', 'count'], 'rush': 'mean'})
#plt.title('Run/Pass ratio')
ax1.scatter(quarterOne.index, quarterOne['pass'])

ax1.axhline(.5, color='grey', linewidth=2)

ax1.set_yticks([.2,.3,.4,.5,.6,.7,.8,])
ax1.set_xticks([-20,-15,-10,-5,0,5,10,15,20])
ax1.set_title('First Quarter')
ax1.set_xlim(-22,22)

ax2.scatter(quarterTwo.index, quarterTwo['pass'])
ax2.axhline(.5, color='grey', linewidth=2)
ax2.set_title('Second Quarter')
#ax2.set_yticks([.2,.3,.4,.5,.6,.7,.8,.9])

ax3.scatter(quarterThree.index, quarterThree['pass'])
ax3.axhline(.5, color='grey', linewidth=2)
ax3.set_title('Third Quarter')

ax4.scatter(quarterFour.index, quarterFour['pass'])
ax4.axhline(.5, color='grey', linewidth=2)
ax4.set_title('Fourth Quarter')

plt.subplots_adjust(bottom=0.25)
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# In the first quarter teams tend to call pass plays on 55% of plays regardless of the score.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)    # The big subplot
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222) 
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)

ax.spines['top'].set_color('none')
ax.spines['bottom'].set_color('none')
ax.spines['left'].set_color('none')
ax.spines['right'].set_color('none')
ax.tick_params(labelcolor='w', top='off', bottom='off', left='off', right='off')

ax1.scatter(quarterOne.index, quarterOne['pass'])

ax1.axhline(.5, color='grey', linewidth=2)

ax1.set_yticks([.2,.3,.4,.5,.6,.7,.8,])
ax1.set_xticks([-20,-15,-10,-5,0,5,10,15,20])
ax1.set_title('First Quarter')
ax1.set_xlim(-22,22)

ax2.scatter(quarterTwo.index, quarterTwo['pass'])
ax2.axhline(.5, color='grey', linewidth=2)
ax2.set_title('Second Quarter')
#ax2.set_yticks([.2,.3,.4,.5,.6,.7,.8,.9])

ax3.scatter(quarterThree.index, quarterThree['pass'])
ax3.axhline(.5, color='grey', linewidth=2)
ax3.set_title('Third Quarter')

ax4.scatter(quarterFour.index, quarterFour['pass'])
ax4.axhline(.5, color='grey', linewidth=2)
ax4.set_title('Fourth Quarter')

ax.set_xlabel('Point Differential')
ax.set_ylabel('Pass/Run Ratio')
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plt.subplots()

ax.scatter(quarterOne.index, quarterOne['pass'])

ax.axhline(.5, color='grey', linewidth=2)

ax.set_yticks([.2,.3,.4,.5,.6,.7,.8,])
ax.set_xticks([-20,-15,-10,-5,0,5,10,15,20])
ax.set_title('First Quarter Pass/Run Differential in relationship to Point Differential')
ax.set_xlim(-22,22)
# Out:
# <img src="data:image/png;base64,...">
# (-22, 22)

# %%
fig, ax = plt.subplots()

ax.scatter(quarterTwo.index, quarterTwo['pass'])
ax.axhline(.5, color='grey', linewidth=2)
ax.set_title('Second Quarter Pass/Run Differential in relationship to Point Differential')
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plt.subplots()

ax.scatter(quarterThree.index, quarterThree['pass'])
ax.axhline(.5, color='grey', linewidth=2)
ax.set_title('Third Quarter Pass/Run Differential in relationship to Point Differential')
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plt.subplots()

ax.scatter(quarterFour.index, quarterFour['pass'])
ax.axhline(.5, color='grey', linewidth=2)
ax.set_Y
ax.set_title('Fourth Quarter Pass/Run Differential in relationship to Point Differential')
# Out:
# <img src="data:image/png;base64,...">

# %%
#Remove overtime 
plays=plays[plays['quarter']!='T']

# %%
plays['time']=plays['time'].apply(pd.to_numeric)/60

# %%
plays.head()
# Out:
#       gsis_id  drive_id pos_team home  home_score away  away_score  pass  \
# 2  2009091000         1      PIT  PIT           0  TEN           0     1
# 3  2009091000         1      PIT  PIT           0  TEN           0     1
# 4  2009091000         1      PIT  PIT           0  TEN           0     0
# 5  2009091000         2      TEN  PIT           0  TEN           0     0
# 6  2009091000         2      TEN  PIT           0  TEN           0     0
#
#    rush quarter      time  pointdiff
# 2     0       1  1.416667          0
# 3     0       1  0.116667          0
# 4     1       1  0.733333          0
# 5     1       1  1.733333          0
# 6     1       1  2.816667          0

# %%
#Convert (Quarters played, time elapsed in quarter) to game time.
#quarter = 15 minutes 
#ie. (Quarter 3, 2 ) = (3-1) quarters played * 15 + 2 =32

#2nd quarter
plays.loc[plays['quarter']== '2', 'time']= plays.loc[plays['quarter']== '2', 'time']+15
#3rd quarter
plays.loc[plays['quarter']== '3', 'time']= plays.loc[plays['quarter']== '3', 'time'] + 30

#4th quarter
plays.loc[plays['quarter']== '4', 'time']= plays.loc[plays['quarter']== '4', 'time']+ 45

# %%
plays=plays.round({'time' : 0})

# %%
fig, ax = plt.subplots()
df=plays.groupby(['time'])['pass', 'rush'].mean()
plt.scatter(df.index, df['pass'])

ax.axhline(.5, color='grey', linewidth=2)
#ax.axvline(30, color='grey', linewidth=4)
#ax.axvline(15, color='grey', linewidth=2)
#ax.axvline(45, color='grey', linewidth=2)
ax.set_xticks([0,15,30, 45, 60])
ax.set_xticklabels(['1st Quarter','2nd Quarter', '3rd Quarter', '4th Quarter' , 'End of Regulation'])
ax.set_xlim(-1,61)


x = ax.xaxis

for item in x.get_ticklabels():
    item.set_rotation(45)
    item.set_horizontalalignment("right")
    
plt.subplots_adjust(bottom=0.25)
# Out:
# <img src="data:image/png;base64,...">

# %%
grouped=plays.groupby(['pointdiff', 'time'])
grouped=grouped.filter(lambda x: len(x) > 5)
pdBytime=grouped.groupby(['pointdiff','time']).agg({'rush': ['mean', 'count'], 'pass': 'mean'})
#pdBytime['rush']
#pdBytime.index[1]
s=pdBytime.index.tolist()
x=zip(*s)
#x[1]

# %%
fig, ax = plt.subplots()
#df=plays.groupby(['time'])['pass', 'rush'].mean()
plt.scatter(x[1], x[0], c=pdBytime['pass'], cmap= 'jet')
#plt.scatter(x, y, c=t, cmap='viridis')
plt.colorbar()
ax.set_xticks([0,15,30, 45,60])
ax.set_xticklabels(['1st Quarter','2nd Quarter', '3rd Quarter', '4th Quarter', 'End of Regulation'])
ax.set_xlim(-5,65)
ax.set_ylabel('Point Differential')

xAxis = ax.xaxis

for item in xAxis.get_ticklabels():
    item.set_rotation(45)
    item.set_horizontalalignment("right")
    
plt.subplots_adjust(bottom=0.25)

plt.title('Run/Pass Ratio based on Point Differential and Remaining Time')
# Out:
# <img src="data:image/png;base64,...">
